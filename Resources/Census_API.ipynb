# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import csv
from pprint import pprint

from census_config import api_key

# %%
# Run Test Call on Census API

url = "https://api.census.gov/data/2018/acs/acs1/profile?get=NAME,DP03_0119PE,DP03_0062E,DP05_0001E&for=urban%20area:*"
api_key = f"&key={api_key}"
census_response = requests.get(url + api_key)
census_response.json()
# Out:
# [['NAME', 'DP03_0119PE', 'DP03_0062E', 'DP05_0001E', 'urban area'],
#  ['Altoona, PA Urbanized Area (2010)', '9.8', '47401', '76539', '01792'],
#  ['Amarillo, TX Urbanized Area (2010)', '11.7', '50287', '203875', '01927'],
#  ['Anniston--Oxford, AL Urbanized Area (2010)',
#   '15.3',
#   '43315',
#   '77109',
#   '02629'],
#  ['Baton Rouge, LA Urbanized Area (2010)', '10.0', '57309', '608183', '05680'],
#  ['Bloomington, IN Urbanized Area (2010)', '12.4', '42740', '115410', '08380'],
#  ['Bloomington--Normal, IL Urbanized Area (2010)',
#   '7.4',
#   '61785',
#   '135143',
#   '08407'],
#  ['Boulder, CO Urbanized Area (2010)', '5.9', '65157', '125220', '09298'],
#  ['Carbondale, IL Urbanized Area (2010)', '14.3', '36717', '68554', '13591'],
#  ['Charleston--North Charleston, SC Urbanized Area (2010)',
#   '9.5',
#   '65221',
#   '645648',
#   '15508'],
#  ['Chico, CA Urbanized Area (2010)', '12.6', '54919', '106641', '16318'],
# ...
