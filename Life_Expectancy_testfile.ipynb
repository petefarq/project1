# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
life_file = "life_expectancy/Life_Expectancy_data_state.csv"
life_file_pd = pd.read_csv(life_file)
life_file_pd.head()
# Out:
#      State          County  Census Tract Number  Life Expectancy  \
# 0  Alabama  Autauga County                201.0             73.1
# 1  Alabama  Autauga County                202.0             76.9
# 2  Alabama  Autauga County                204.0             75.4
# 3  Alabama  Autauga County                205.0             79.4
# 4  Alabama  Autauga County                206.0             73.1
#
#   Life Expectancy Range  Life Expectancy Standard Error
# 0           56.3 - 75.0                          2.2348
# 1           75.1 - 77.4                          3.3453
# 2           75.1 - 77.4                          1.0216
# 3           77.5 - 79.4                          1.1768
# 4           56.3 - 75.0                          1.5519

# %%
clean_life_df = life_file_pd.dropna(how = "any")
clean_life_df.count()


life_group = clean_life_df.groupby(["County"])
life_group.count().head(10)
# Out:
#                   State  Census Tract Number  Life Expectancy  \
# County
# Abbeville County      6                    6                6
# Acadia Parish        11                   11               11
# Accomack County       8                    8                8
# Ada County           59                   59               59
# Adair County         20                   20               20
# Adams County        147                  147              147
# Adams County, PA     22                   22               22
# Addison County       10                   10               10
# Aiken County         30                   30               30
# Aitkin County         6                    6                6
#
#                   Life Expectancy Range  Life Expectancy Standard Error
# County
# Abbeville County                      6                               6
# Acadia Parish                        11                              11
# ...

# %%
# Out:
# State                             65662
# County                            65662
# Census Tract Number               65662
# Life Expectancy                   65662
# Life Expectancy Range             65662
# Life Expectancy Standard Error    65662
# dtype: int64
